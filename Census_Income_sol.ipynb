# %% [markdown]
# # Census Income Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\DELL\\Desktop\\Data Trained\\Evaluation Projects\\census_income.csv')
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### There are 0 values present in Capital_gain and Capital_loss columns.

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df['Workclass'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %% [markdown]
# ### The '?' in the data can be considered as unknown in all columns.

# %%
df['Education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df['Marital_status'].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['Relationship'].unique()
# Out:
# array([' Husband', ' Not-in-family', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
df['Race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df['Sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['Native_country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
sns.countplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# ### Most of the people's income is less than 50k.

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['Workclass'],hue=df['Income'])
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %% [markdown]
# ### Most of the people works in private sector.

# %%
plt.figure(figsize=(19,5))
sns.countplot(df['Education'],hue=df['Income'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# ### People with Masters, Doctorates and who works as Professer earns more.
# ### More than half of bachelors degree people has selary greater than 50k.

# %%
plt.figure(figsize=(24,5))
sns.countplot(df['Occupation'],hue=df['Income'])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ### People who are having Executive Manager, Prof-Specialty as their occupation earns more.

# %%
plt.figure(figsize=(20,5))
sns.countplot(df['Marital_status'],hue=df['Income'])
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# ### Married-civ-spouse people earns more than other

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['Race'],hue=df['Income'])
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %% [markdown]
# ### Comparitively Whites and Asian-Pac-Islanders earns more than other race people.

# %%
sns.lineplot(df['Income'],df['Age'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Age'>

# %% [markdown]
# ### As age increases, income also increases due to experience.

# %%
plt.figure(figsize=(15,5))
sns.lineplot(df['Income'],df['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Fnlwgt'>

# %% [markdown]
# ### If final weight is less than that means the income is more.

# %%
plt.figure(figsize=(15,5))
sns.lineplot(df['Income'],df['Hours_per_week'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Hours_per_week'>

# %% [markdown]
# ### As we know already, working more hours will fetch us good income.

# %%
df['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
t=['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']# Continuous variables
v=['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']

# %%
for i in t:
    plt.figure(figsize=(4,4))
    sns.distplot(df[i])

# %% [markdown]
# ### Final weights, Education_num, Hours_per_week are not not normally distributed and skewness is present in almost all columns.

# %%
for i in t:
    plt.figure(figsize=(4,4))
    sns.boxplot(df[i])

# %% [markdown]
# ### Outliers are present in all the columns.

# %%
gain=set(df['Capital_gain'])
loss=set(df['Capital_loss'])

# %%
gain=sorted(gain)[1]
loss=sorted(loss)[1]
print(gain,loss)
# Out:
# 114 155

# %%
df['Capital_gain'] = df['Capital_gain'].replace(0,gain)
df['Capital_loss'] = df['Capital_loss'].replace(0,loss)

# %% [markdown]
# ### Here, we have replaced the 0 values with minimum gain and minimum loss of respective columns

# %% [markdown]
# ## Outliers Removal

# %%
for i in t:
    Q1=df[i].quantile(0.25)
    Q3=df[i].quantile(0.75)
    IQR=Q3-Q1
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    whisker_width = 1.5
    outliers = df[(df[i] < Q1 - whisker_width*IQR) | (df[i] > Q3 + whisker_width*IQR)]
    
    fare_mean = df[i].mean()
    fare_std = df[i].std()
    low= fare_mean -(3 * fare_std)
    high= fare_mean + (3 * fare_std)
    fare_outliers = df[(df[i] < low) | (df[i] > high)]
    
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    whisker_width = 1.5
    lower_whisker = Q1 -(whisker_width*IQR)
    upper_whisker = Q3 +(whisker_width*IQR)
    df[i]=np.where(df[i]>upper_whisker,upper_whisker,np.where(df[i]<lower_whisker,lower_whisker,df[i]))

# %% [markdown]
# ### Instead of eliminating the outliers, we have replaced the outliers higher than the upper whisker by the value of upper whisker and the outliers lower than the lower whisker by the value of lower whisker.

# %%
for i in t:
    plt.figure(figsize=(4,4))
    sns.boxplot(df[i])

# %% [markdown]
# ### Outliers have been removed.

# %% [markdown]
# ## Skewness

# %%
df.skew()
# Out:
# Age               0.513883
# Fnlwgt            0.548285
# Education_num    -0.034043
# Capital_gain      0.000000
# Capital_loss      0.000000
# Hours_per_week    0.438274
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method = 'yeo-johnson')
f=['Age','Fnlwgt']
for i in f:
    df[i] = pt.fit_transform(np.array(df[i]).reshape(-1,1))[:,0]

# %%
df.skew()
# Out:
# Age              -0.016371
# Fnlwgt           -0.047462
# Education_num    -0.034043
# Capital_gain      0.000000
# Capital_loss      0.000000
# Hours_per_week    0.438274
# dtype: float64

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for i in v:
    df[i]=lab.fit_transform(df[i].values.reshape(-1,1))

# %%
df.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0  0.894611          6 -1.122124          9           13.0               2
# 1  0.100530          4  0.404206         11            9.0               0
# 2  1.068672          4  0.583674          1            7.0               2
# 3 -0.734220          4  1.463450          9           13.0               2
# 4  0.025600          4  1.024488         12           14.0               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1         114.0         155.0
# 1           6             1     4    1         114.0         155.0
# 2           6             0     2    1         114.0         155.0
# 3          10             5     2    0         114.0         155.0
# 4           4             5     4    0         114.0         155.0
#
#    Hours_per_week  Native_country  Income
# 0            32.5              39       0
# ...

# %%
cor=df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(['Income'],axis=1)
y=df['Income']

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0  0.894611   1.463883 -1.122124  -0.335443       1.169145       -0.406183
# 1  0.100530   0.090121  0.404206   0.181319      -0.457057       -1.734026
# 2  1.068672   0.090121  0.583674  -2.402489      -1.270159       -0.406183
# 3 -0.734220   0.090121  1.463450  -0.335443       1.169145       -0.406183
# 4  0.025600   0.090121  1.024488   0.439700       1.575696       -0.406183
#
#    Occupation  Relationship      Race       Sex  Capital_gain  Capital_loss  \
# 0   -0.608434     -0.900177  0.393675  0.703087           0.0           0.0
# 1   -0.135480     -0.277810  0.393675  0.703087           0.0           0.0
# 2   -0.135480     -0.900177 -1.962583  0.703087           0.0           0.0
# 3    0.810427      2.211658 -1.962583 -1.422298           0.0           0.0
# 4   -0.608434      2.211658  0.393675 -1.422298           0.0           0.0
#
#    Hours_per_week  Native_country
# ...

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['col']=x.columns
vif
# Out:
#          vif             col
# 0   1.200404             Age
# 1   1.091600       Workclass
# 2   1.011195          Fnlwgt
# 3   1.152764       Education
# 4   1.205913   Education_num
# 5   1.150939  Marital_status
# 6   1.092778      Occupation
# 7   1.690571    Relationship
# 8   1.039210            Race
# 9   1.566357             Sex
# 10       NaN    Capital_gain
# 11       NaN    Capital_loss
# 12  1.169652  Hours_per_week
# 13  1.027688  Native_country

# %% [markdown]
# ### There is no multi collinearity in the given data.

# %% [markdown]
# ## Sampling

# %%
from imblearn.over_sampling import SMOTE
smo=SMOTE()
x,y=smo.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    24719
# 1    24719
# Name: Income, dtype: int64

# %% [markdown]
# ## Choosing Random State Value

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report
maxac=0
maxran=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    sam=DecisionTreeClassifier()
    sam.fit(x_train,y_train)
    pred=sam.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxac:
        maxac=acc
        maxran=i
print('max accuracy=',maxac,'ran state=',maxran)
# Out:
# max accuracy= 0.8466828478964401 ran state= 60

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=maxran)

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred1=dtc.predict(x_test)
dtc_clas1=classification_report(y_test,pred1)
acc1=accuracy_score(y_test,pred1)
print(acc1)
print(dtc_clas1)
# Out:
# 0.8457726537216829
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      4978
#            1       0.84      0.85      0.85      4910
#
#     accuracy                           0.85      9888
#    macro avg       0.85      0.85      0.85      9888
# weighted avg       0.85      0.85      0.85      9888

# %%
from sklearn.metrics import confusion_matrix
con1=confusion_matrix(y_test,pred1)
con1
# Out:
# array([[4198,  780],
#        [ 745, 4165]], dtype=int64)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr, tpr, thresholds =roc_curve(y_test, pred1)
area_under_curve=roc_auc_score(y_test, pred1)
# Printing ROC curve
plt.plot(fpr,tpr,label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC Curve(area=%0.3f)'%area_under_curve)
plt.legend()
plt.show()

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
pred2=rfc.predict(x_test)
rfc_clas2=classification_report(y_test,pred2)
acc2=accuracy_score(y_test,pred2)
print(acc2)
print(rfc_clas2)
# Out:
# 0.8923948220064725
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      4978
#            1       0.88      0.90      0.89      4910
#
#     accuracy                           0.89      9888
#    macro avg       0.89      0.89      0.89      9888
# weighted avg       0.89      0.89      0.89      9888

# %%
con2=confusion_matrix(y_test,pred2)
con2
# Out:
# array([[4390,  588],
#        [ 476, 4434]], dtype=int64)

# %%
fpr, tpr, thresholds =roc_curve(y_test, pred2)
area_under_curve=roc_auc_score(y_test, pred2)
# Printing ROC curve
plt.plot(fpr,tpr,label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC Curve(area=%0.3f)'%area_under_curve)
plt.legend()
plt.show()

# %% [markdown]
# ### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn1=KNeighborsClassifier()
knn1.fit(x_train,y_train)
pred3=knn1.predict(x_test)
sv_clas3=classification_report(y_test,pred3)
acc3=accuracy_score(y_test,pred3)
print(acc3)
print(sv_clas3)
# Out:
# 0.8558859223300971
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84      4978
#            1       0.81      0.93      0.87      4910
#
#     accuracy                           0.86      9888
#    macro avg       0.86      0.86      0.86      9888
# weighted avg       0.86      0.86      0.86      9888

# %%
con3=confusion_matrix(y_test,pred3)
con3
# Out:
# array([[3884, 1094],
#        [ 331, 4579]], dtype=int64)

# %%
fpr, tpr, thresholds =roc_curve(y_test, pred3)
area_under_curve=roc_auc_score(y_test, pred3)
# Printing ROC curve
plt.plot(fpr,tpr,label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC Curve(area=%0.3f)'%area_under_curve)
plt.legend()
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
pred4=lr.predict(x_test)
lr_clas4=classification_report(y_test,pred4)
acc4=accuracy_score(y_test,pred4)
print(acc4)
print(lr_clas4)
# Out:
# 0.7557645631067961
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75      4978
#            1       0.74      0.78      0.76      4910
#
#     accuracy                           0.76      9888
#    macro avg       0.76      0.76      0.76      9888
# weighted avg       0.76      0.76      0.76      9888

# %%
con4=confusion_matrix(y_test,pred4)
con4
# Out:
# array([[3656, 1322],
#        [1093, 3817]], dtype=int64)

# %%
fpr, tpr, thresholds =roc_curve(y_test, pred4)
area_under_curve=roc_auc_score(y_test, pred4)
# Printing ROC curve
plt.plot(fpr,tpr,label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC Curve(area=%0.3f)'%area_under_curve)
plt.legend()
plt.show()

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv1=cross_val_score(dtc,x,y,cv=15).mean()
cv2=cross_val_score(rfc,x,y,cv=15).mean()
cv3=cross_val_score(knn1,x,y,cv=15).mean()
cv4=cross_val_score(lr,x,y,cv=15).mean()
print(cv1,cv2,cv3,cv4)
# Out:
# 0.838546844537423 0.8894791559241961 0.8505203407143312 0.7526195667653747

# %%
print((acc1-cv1),(acc2-cv2),(acc3-cv3),(acc4-cv4))
# Out:
# 0.007225809184259857 0.002915666082276336 0.005365581615765835 0.003144996341421402

# %% [markdown]
# ### We can choose Random Forest Classifier as our model since its cv_score and accuracy score are almost similar.

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'max_features':['auto', 'sqrt', 'log2'],'criterion':['gini', 'entropy'],'max_depth':list(range(5,15)),
            'max_leaf_nodes':list(range(5,15))}
gsc=GridSearchCV(rfc,parameters)
gsc.fit(x_train,y_train)
print(gsc.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'max_leaf_nodes': 14}

# %%
fin_income_model=RandomForestClassifier(max_features='sqrt',criterion='gini',max_depth=8 ,max_leaf_nodes=14 )
fin_income_model.fit(x_train,y_train)
pred5=fin_income_model.predict(x_test)
sv_acc=accuracy_score(y_test,pred5)
print("Final_Accuracy:",sv_acc*100)
# Out:
# Final_Accuracy: 82.25121359223301

# %% [markdown]
# ### Due to high number of rows, while doing Hyper Parameter Tuning, it is taking more than 10 hours to run the code. Because of this problem, I am continuing with the above parameters.

# %%
con5=confusion_matrix(y_test,pred5)
con5
# Out:
# array([[3859, 1119],
#        [ 636, 4274]], dtype=int64)

# %%
fpr, tpr, thresholds =roc_curve(y_test, pred5)
area_under_curve=roc_auc_score(y_test, pred5)
# Print ROC curve
plt.plot(fpr,tpr,label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC Curve(area=%0.3f)'%area_under_curve)
plt.legend()
plt.show()

# %% [markdown]
# ## Saving the Model

# %%
import joblib
joblib.dump(fin_income_model,'Final_income_mod.pkl')
# Out:
# ['Final_income_mod.pkl']
